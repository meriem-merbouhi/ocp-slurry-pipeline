# %%
# Vérification que Spark fonctionne
print(f"Spark version : {spark.version}")
print("✅ Databricks Community Edition opérationnel !")
# Out:
# Spark version : 4.1.0
# ✅ Databricks Community Edition opérationnel !

# %%
# Lire les données uploadées
df = spark.read.option("header", True).option("inferSchema", True).csv(
    "/Volumes/workspace/default/bronze/ai4i2020.csv"
)

print(f"✅ Lignes : {df.count()}")
print(f"✅ Colonnes : {len(df.columns)}")
df.show(5)
# Out:
# ✅ Lignes : 10000
# ✅ Colonnes : 14
# +---+----------+----+-------------------+-----------------------+----------------------+-----------+---------------+---------------+---+---+---+---+---+
# |UDI|Product ID|Type|Air temperature [K]|Process temperature [K]|Rotational speed [rpm]|Torque [Nm]|Tool wear [min]|Machine failure|TWF|HDF|PWF|OSF|RNF|
# +---+----------+----+-------------------+-----------------------+----------------------+-----------+---------------+---------------+---+---+---+---+---+
# |  1|    M14860|   M|              298.1|                  308.6|                  1551|       42.8|              0|              0|  0|  0|  0|  0|  0|
# |  2|    L47181|   L|              298.2|                  308.7|                  1408|       46.3|              3|              0|  0|  0|  0|  0|  0|
# |  3|    L47182|   L|              298.1|                  308.5|                  1498|       49.4|              5|              0|  0|  0|  0|  0|  0|
# ...
